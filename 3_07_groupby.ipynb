# %% [markdown]
# <a href="https://colab.research.google.com/github/sokhan1/Programming-solution/blob/main/3_07_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #df.groupby()
#
#
# *   Aggregation is the process of grouping data according to certain criteria and then aggregating it based on those criteria. You need to set the criteria for grouping and the criteria for the specific operation or calculation that will be used for aggregation.
# *   process
#
#     *   Splitting(분할)
#     *   Applying(적용)
#     *   Combining(결합)
#
#
#
#     *   df.groupby( by= 'col_group')['col_agg'].agg_func().reset_index()

# %%
import pandas as pd
df=pd.DataFrame({
    'group': ['A', 'A', 'B', 'B', 'C', 'C'],
    'value': [10, 10, 30, 40, 60, 60]
})

# %%
df
# Out:
#   group  value
# 0     A     10
# 1     A     10
# 2     B     30
# 3     B     40
# 4     C     60
# 5     C     60

# %%
print('A:', df[df.group == 'A'])
print('B:', df[df.group == 'B'])
print('C:', df[df.group == 'C'])
# Out:
# A:   group  value
# 0     A     10
# 1     A     10
# B:   group  value
# 2     B     30
# 3     B     40
# C:   group  value
# 4     C     60
# 5     C     60

# %% [markdown]
# #Applying(적용)
#
# *   Apply the function to each group independently.
# *   In Pandas, aggregation functions like sum, mean, max, and min are applied to numeric data by default (sum, max, etc. are applied but not used), whereas count and nunique functions are applied to all data types (numbers, strings, etc.).

# %%
print('A:',df[df.group == 'A']['value'].sum())
print('B:',df[df.group == 'B']['value'].sum())
print('C:',df[df.group == 'C']['value'].sum())
# Out:
# A: 20
# B: 70
# C: 120

# %% [markdown]
# # Combining(결합)
#
# *   Combine results into a single data structure

# %%
df.groupby( by= 'group')['value'].sum().reset_index()
# Out:
#   group  value
# 0     A     20
# 1     B     70
# 2     C    120

# %% [markdown]
# #reset_index()
#
#
# *   Make a index column

# %%
df.groupby( by= 'group')['value'].sum()
# Out:
# group
# A     20
# B     70
# C    120
# Name: value, dtype: int64

# %% [markdown]
# ##Aggregation(집계)
#
#
# *   1. sum, mean, max, min: these functions work on numeric data (strings are an error)

# %%
df.groupby( by= 'group')['value'].sum().reset_index()
# Out:
#   group  value
# 0     A     20
# 1     B     70
# 2     C    120

# %%
df.groupby( by= 'group')['value'].std().reset_index()
# Out:
#   group     value
# 0     A  0.000000
# 1     B  7.071068
# 2     C  0.000000

# %%
df
# Out:
#   group  value
# 0     A     10
# 1     A     10
# 2     B     30
# 3     B     40
# 4     C     60
# 5     C     60

# %%
df.groupby( by= 'group')['value'].count().reset_index()
# Out:
#   group  value
# 0     A      2
# 1     B      2
# 2     C      2

# %%
import pandas as pd
df2=pd.DataFrame({
    'group': ['A', 'A', 'B', 'B', 'C', 'C'],
    'value': [10, 10, 30, 40, 60, 60],
    'value2': [None,'d','d','s',None,None]
})

# %%
df2.groupby( by= 'group')['value2'].count().reset_index() #None is not counted
# Out:
#   group  value2
# 0     A       1
# 1     B       2
# 2     C       0

# %%
df2.groupby( by= 'group')['value2'].nunique().reset_index() #Duplicate values do not exist
# Out:
#   group  value2
# 0     A       1
# 1     B       2
# 2     C       0

# %%
import pandas as pd
df3=pd.DataFrame({
    'group': ['A', 'A', 'B', 'B', 'C', 'C'],
    'value': [10, 10, 30, 40, 60, 60],
    'value2': [None,'d','d','d',None,None]
})

# %%
df3.groupby( by= 'group')['value2'].nunique().reset_index() #Duplicate values  exist
# Out:
#   group  value2
# 0     A       1
# 1     B       1
# 2     C       0

# %% [markdown]
# #groupby.agg()
#
#
# *   Performing multiple aggregation operations
#
#
#     *   df.groupby(by='group').agg(
#         col_name1 = ('col1','agg_func')
#         , col_name2 = ('col2','agg_func')
#         ).reset_index()
#         # agg_func -> sum,mean,max,min, ...

# %%
df3.groupby(by='group')['value2'].nunique().reset_index()
# Out:
#   group  value2
# 0     A       1
# 1     B       1
# 2     C       0

# %%
df3.groupby(by='group').agg(
    col_name1 = ('value2','nunique')
    , val1_sum = ('value','sum')
    ).reset_index()
# Out:
#   group  col_name1  val1_sum
# 0     A          1        20
# 1     B          1        70
# 2     C          0       120

# %% [markdown]
# #Exercise
#
#
# Grouping and aggregation with the Titanic dataset
# *   Group the data by 'Pclass', and perform the following aggregation operation on each group
#     1.   Sum of the Survived column (number of survivors)
#     2.   Fare column의 평균 (평균 요금)
#     3.   Number of eigenvalues in the Embarked column (number of ports of departure)

# %%
import seaborn as sns
df_ex=sns.load_dataset('titanic', cache = False)
df_ex.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_ex.groupby( by= 'pclass')['survived'].sum().reset_index()
# Out:
#    pclass  survived
# 0       1       136
# 1       2        87
# 2       3       119

# %%
df_ex.groupby( by= 'pclass')['fare'].mean().reset_index()
# Out:
#    pclass       fare
# 0       1  84.154687
# 1       2  20.662183
# 2       3  13.675550

# %%
df_ex.groupby( by= 'pclass')['embark_town'].nunique().reset_index()
# Out:
#    pclass  embark_town
# 0       1            3
# 1       2            3
# 2       3            3

# %%
df_ex.groupby(by='pclass').agg(
    survived_sum = ('survived','sum')
    , fare_mean = ('fare','mean')
    , embarked_unique =('embark_town','nunique')
    ).reset_index()
# Out:
#    pclass  survived_sum  fare_mean  embarked_unique
# 0       1           136  84.154687                3
# 1       2            87  20.662183                3
# 2       3           119  13.675550                3
